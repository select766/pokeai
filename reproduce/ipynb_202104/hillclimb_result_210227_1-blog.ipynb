# %%
# ループ学習での各iterationの出現ポケモン数統計

# %%
from pokeai.ai.party_db import col_party, col_rate, pack_obj, unpack_obj
from bson import ObjectId
import numpy as np
from pokeai.util import json_load, pickle_load, ROOT_DIR, DATASET_DIR
from collections import Counter
import random

# %%
# https://stackoverflow.com/questions/2158395/flatten-an-irregular-list-of-lists
from collections.abc import Iterable

def flatten(l):
    for el in l:
        if isinstance(el, Iterable) and not isinstance(el, (str, bytes)):
            yield from flatten(el)
        else:
            yield el

# %%
def load_parties(tag):
    return [doc["party"] for doc in col_party.find({"tags": tag})]

# %%
name2jp = json_load(DATASET_DIR.joinpath("name2jp.json"))["name2jp"]
def print_party(p):
    for poke in p:
        print(",".join([name2jp[poke["species"]],"LV"+str(poke["level"]), *[name2jp[move] for move in poke["moves"]]]))

# %%
def display_hindo(items):
    c = Counter(items)
    print("|要素|出現回数|")
    print("|---|---|")
    for k, v in c.most_common(20):
        print(f"|{name2jp[k]}|{v}|")

# %%
def display_hindo_poke(parties):
    display_hindo(flatten([[pk["species"] for pk in p] for p in parties]))

# %%
def display_hindo_move(parties):
    display_hindo(flatten([[pk["moves"] for pk in p] for p in parties]))

# %%
def display_hindo_all(parties):
    display_hindo_poke(parties)
    print()
    display_hindo_move(parties)
    print()

# %%
file_base_dir = r"D:\dev\pokeai\pokeai\experiment\team\rl\rl_loop_210227_1"
iter_ids = json_load(file_base_dir+"/iter_ids.json")
iter_ids
# Out:
# [{'iternum': 0,
#   'trainer_id': '6039caccaf28292a4eae380a',
#   'train_party_tags': ['rl_loop_210227_1_allonce_0', 'rl_loop_210227_1_hc_0'],
#   'gen_party_tag': 'rl_loop_210227_1_hc_1',
#   'rate_id': '6049e2cd3410a8cbf644a642'},
#  {'iternum': 1,
#   'trainer_id': '6039caccaf28292a4eae380b',
#   'train_party_tags': ['rl_loop_210227_1_allonce_1', 'rl_loop_210227_1_hc_1'],
#   'gen_party_tag': 'rl_loop_210227_1_hc_2',
#   'rate_id': '6049e2cd3410a8cbf644a643'},
#  {'iternum': 2,
#   'trainer_id': '6039caccaf28292a4eae380c',
#   'train_party_tags': ['rl_loop_210227_1_allonce_2', 'rl_loop_210227_1_hc_2'],
#   'gen_party_tag': 'rl_loop_210227_1_hc_3',
#   'rate_id': '6049e2cd3410a8cbf644a644'},
#  {'iternum': 3,
#   'trainer_id': '6039caccaf28292a4eae380d',
#   'train_party_tags': ['rl_loop_210227_1_allonce_3', 'rl_loop_210227_1_hc_3'],
#   'gen_party_tag': 'rl_loop_210227_1_hc_4',
#   'rate_id': '6049e2cd3410a8cbf644a645'},
#  {'iternum': 4,
#   'trainer_id': '6039caccaf28292a4eae380e',
#   'train_party_tags': ['rl_loop_210227_1_allonce_4', 'rl_loop_210227_1_hc_4'],
#   'gen_party_tag': 'rl_loop_210227_1_hc_5',
#   'rate_id': '6049e2cd3410a8cbf644a646'},
#  {'iternum': 5,
#   'trainer_id': '6039caccaf28292a4eae380f',
#   'train_party_tags': ['rl_loop_210227_1_allonce_5', 'rl_loop_210227_1_hc_5'],
#   'gen_party_tag': 'rl_loop_210227_1_hc_6',
#   'rate_id': '6049e2cd3410a8cbf644a647'},
#  {'iternum': 6,
#   'trainer_id': '6039caccaf28292a4eae3810',
#   'train_party_tags': ['rl_loop_210227_1_allonce_6', 'rl_loop_210227_1_hc_6'],
#   'gen_party_tag': 'rl_loop_210227_1_hc_7',
#   'rate_id': '6049e2cd3410a8cbf644a648'},
#  {'iternum': 7,
#   'trainer_id': '6039caccaf28292a4eae3811',
#   'train_party_tags': ['rl_loop_210227_1_allonce_7', 'rl_loop_210227_1_hc_7'],
#   'gen_party_tag': 'rl_loop_210227_1_hc_8',
#   'rate_id': '6049e2cd3410a8cbf644a649'},
#  {'iternum': 8,
#   'trainer_id': '6039caccaf28292a4eae3812',
#   'train_party_tags': ['rl_loop_210227_1_allonce_8', 'rl_loop_210227_1_hc_8'],
#   'gen_party_tag': 'rl_loop_210227_1_hc_9',
#   'rate_id': '6049e2cd3410a8cbf644a64a'},
#  {'iternum': 9,
#   'trainer_id': '6039caccaf28292a4eae3813',
#   'train_party_tags': ['rl_loop_210227_1_allonce_9', 'rl_loop_210227_1_hc_9'],
#   'gen_party_tag': 'rl_loop_210227_1_hc_10',
#   'rate_id': '6049e2cd3410a8cbf644a64b'}]

# %%
tags = [iterinfo["train_party_tags"][1] for iterinfo in iter_ids]
penalties = [iterinfo["iternum"] for iterinfo in iter_ids]#改造の都合でpenaltyになってるがiteration number
tag_to_penalty = {tag:penalty for tag,penalty in zip(tags, penalties)}

# %%
parties_tag = {tag:load_parties(tag) for tag in tags}

# %%
parties_penalty = {tag_to_penalty[tag]:parties_tag[tag] for tag in tags}

# %%
for tag, parties in parties_tag.items():
    print(tag, tag_to_penalty[tag])
    display_hindo_all(parties)
# Out:
# rl_loop_210227_1_hc_0 0
# |要素|出現回数|
# |---|---|
# |ゴローニャ|31|
# |ランターン|30|
# |ブースター|29|
# |エレブー|29|
# |ワタッコ|29|
# |ライチュウ|29|
# |オムスター|28|
# |サワムラー|28|
# |ヤンヤンマ|27|
# |エビワラー|27|
# |レディアン|27|
# |カメックス|26|
# |バリヤード|26|
# |アズマオウ|26|
# |ニョロトノ|26|
# |マンタイン|26|
# |アーボック|25|
# |リングマ|25|
# |キマワリ|25|
# |ウソッキー|25|
#
# |要素|出現回数|
# |---|---|
# |どくどく|677|
# |おんがえし|672|
# |かげぶんしん|641|
# |はかいこうせん|539|
# |とっしん|502|
# |ずつき|467|
# |すてみタックル|445|
# |どろかけ|409|
# |スピードスター|401|
# |のしかかり|318|
# |いわくだき|312|
# |かいりき|301|
# |ロケットずつき|268|
# |ばくれつパンチ|201|
# |れいとうビーム|196|
# |でんじほう|190|
# |１０まんボルト|180|
# |なみのり|180|
# |かみなり|174|
# |じしん|171|
#
# rl_loop_210227_1_hc_1 1
# |要素|出現回数|
# |---|---|
# |バンギラス|111|
# |カビゴン|89|
# |エーフィ|76|
# |エンテイ|72|
# |サンダー|67|
# |ライコウ|61|
# |シャワーズ|59|
# |ラプラス|49|
# |ケンタロス|49|
# |フーディン|43|
# |ゲンガー|43|
# |スイクン|40|
# |キングドラ|38|
# |カイリュー|38|
# |バクフーン|37|
# |ミルタンク|33|
# |ヤドキング|30|
# |ニョロボン|28|
# |サンダース|27|
# |スターミー|27|
#
# |要素|出現回数|
# |---|---|
# |おんがえし|579|
# |かげぶんしん|464|
# |どくどく|419|
# |１０まんボルト|399|
# |はかいこうせん|363|
# |ずつき|355|
# |のしかかり|343|
# |とっしん|341|
# |どろかけ|321|
# |なみのり|320|
# |すてみタックル|316|
# |じしん|299|
# |れいとうビーム|291|
# |スピードスター|266|
# |いわくだき|264|
# |かいりき|261|
# |サイコキネシス|259|
# |だいもんじ|245|
# |ロケットずつき|234|
# |かみなり|216|
#
# rl_loop_210227_1_hc_2 2
# |要素|出現回数|
# |---|---|
# |カビゴン|119|
# |サンダー|105|
# |スターミー|86|
# |ライコウ|68|
# |カイリュー|62|
# |キングドラ|61|
# |ラプラス|59|
# |デンリュウ|49|
# |バンギラス|48|
# |プテラ|46|
# |ベトベトン|46|
# |キレイハナ|45|
# |ゲンガー|37|
# |カメックス|33|
# |ヤドラン|33|
# |フシギバナ|31|
# |ジュゴン|30|
# |ヤドキング|30|
# |ヌオー|30|
# |ハピナス|30|
#
# |要素|出現回数|
# |---|---|
# |おんがえし|467|
# |どくどく|427|
# |かげぶんしん|422|
# |のしかかり|403|
# |はかいこうせん|379|
# |すてみタックル|359|
# |じしん|352|
# |１０まんボルト|349|
# |ずつき|318|
# |とっしん|306|
# |れいとうビーム|290|
# |かいりき|286|
# |かみなり|271|
# |どろかけ|271|
# |スピードスター|254|
# |いわくだき|246|
# |でんじほう|243|
# |なみのり|228|
# |ふぶき|213|
# |ばくれつパンチ|208|
#
# rl_loop_210227_1_hc_3 3
# |要素|出現回数|
# |---|---|
# |カビゴン|120|
# |バクフーン|104|
# |サンダー|78|
# |バンギラス|77|
# |ランターン|70|
# |ファイヤー|62|
# |ポリゴン２|57|
# |ライコウ|39|
# |ガルーラ|39|
# |ハピナス|39|
# |リングマ|38|
# |スターミー|38|
# |フーディン|37|
# |エーフィ|32|
# |ニドクイン|32|
# |ケンタロス|31|
# |サイドン|30|
# |カイリキー|30|
# |イノムー|29|
# |エアームド|29|
#
# |要素|出現回数|
# |---|---|
# |おんがえし|648|
# |かげぶんしん|431|
# |どくどく|410|
# |はかいこうせん|401|
# |じしん|397|
# |とっしん|359|
# |すてみタックル|356|
# |１０まんボルト|344|
# |れいとうビーム|337|
# |どろかけ|323|
# |のしかかり|318|
# |ずつき|318|
# |いわくだき|250|
# |スピードスター|249|
# |かいりき|242|
# |なみのり|229|
# |ロケットずつき|220|
# |だいもんじ|217|
# |かみなり|210|
# |ばくれつパンチ|207|
#
# rl_loop_210227_1_hc_4 4
# |要素|出現回数|
# |---|---|
# |カビゴン|123|
# |ラプラス|99|
# |サンダー|83|
# |キングドラ|78|
# |ライコウ|60|
# |エンテイ|56|
# |ケンタロス|53|
# |バンギラス|51|
# |スイクン|46|
# |ガルーラ|45|
# |カイリュー|40|
# |フーディン|40|
# |ヤドキング|38|
# |スターミー|35|
# |ドククラゲ|34|
# |ランターン|32|
# |ヤドラン|31|
# |ナッシー|31|
# |リングマ|30|
# |シャワーズ|28|
#
# |要素|出現回数|
# |---|---|
# |おんがえし|651|
# |どくどく|429|
# |はかいこうせん|415|
# |なみのり|380|
# |かげぶんしん|380|
# |のしかかり|377|
# |１０まんボルト|363|
# |じしん|352|
# |とっしん|352|
# |ずつき|345|
# |れいとうビーム|314|
# |すてみタックル|302|
# |どろかけ|283|
# |スピードスター|263|
# |いわくだき|246|
# |でんじほう|234|
# |かいりき|229|
# |ロケットずつき|227|
# |かみなり|226|
# |ふぶき|208|
#
# rl_loop_210227_1_hc_5 5
# |要素|出現回数|
# |---|---|
# |カビゴン|101|
# |ガルーラ|63|
# |ミルタンク|58|
# |ライコウ|57|
# |サンダー|54|
# |バンギラス|52|
# |スターミー|50|
# |オドシシ|48|
# |デンリュウ|48|
# |ナッシー|47|
# |サンダース|43|
# |イノムー|41|
# |ラプラス|37|
# |ルージュラ|36|
# |リザードン|35|
# |ファイヤー|33|
# |カイリュー|33|
# |ゲンガー|33|
# |ライチュウ|32|
# |エレブー|31|
#
# |要素|出現回数|
# |---|---|
# |おんがえし|717|
# |のしかかり|514|
# |どくどく|444|
# |かげぶんしん|418|
# |じしん|400|
# |はかいこうせん|352|
# |１０まんボルト|341|
# |ずつき|315|
# |とっしん|314|
# |すてみタックル|306|
# |どろかけ|302|
# |れいとうビーム|278|
# |いわくだき|266|
# |なみのり|264|
# |スピードスター|261|
# |かみなり|245|
# |かいりき|235|
# |ロケットずつき|227|
# |サイコキネシス|213|
# |ふぶき|213|
#
# rl_loop_210227_1_hc_6 6
# |要素|出現回数|
# |---|---|
# |カビゴン|121|
# |サンダー|82|
# |ケンタロス|73|
# |バンギラス|61|
# |ヘルガー|60|
# |ヤドラン|52|
# |エーフィ|50|
# |ラプラス|47|
# |フーディン|44|
# |ポリゴン２|42|
# |スイクン|40|
# |ヤドキング|40|
# |ナッシー|37|
# |キングドラ|35|
# |スターミー|34|
# |ドククラゲ|31|
# |ピクシー|30|
# |ファイヤー|30|
# |リザードン|30|
# |プテラ|29|
#
# |要素|出現回数|
# |---|---|
# |おんがえし|629|
# |かげぶんしん|429|
# |どくどく|400|
# |れいとうビーム|370|
# |じしん|362|
# |すてみタックル|352|
# |はかいこうせん|352|
# |ずつき|330|
# |のしかかり|326|
# |どろかけ|314|
# |とっしん|304|
# |なみのり|296|
# |スピードスター|292|
# |いわくだき|267|
# |かいりき|262|
# |サイコキネシス|254|
# |ロケットずつき|248|
# |１０まんボルト|242|
# |だいもんじ|229|
# |でんじほう|226|
#
# rl_loop_210227_1_hc_7 7
# |要素|出現回数|
# |---|---|
# |カビゴン|102|
# |サンダー|94|
# |シャワーズ|70|
# |バンギラス|56|
# |ライコウ|55|
# |スターミー|54|
# |フーディン|50|
# |ガルーラ|48|
# |ラプラス|47|
# |ミルタンク|47|
# |キングドラ|43|
# |ランターン|39|
# |ギャラドス|38|
# |サンダース|38|
# |ドードリオ|36|
# |プテラ|36|
# |ペルシアン|35|
# |エンテイ|34|
# |ヤドラン|32|
# |フリーザー|32|
#
# |要素|出現回数|
# |---|---|
# |おんがえし|633|
# |１０まんボルト|418|
# |どくどく|410|
# |のしかかり|395|
# |かげぶんしん|390|
# |はかいこうせん|361|
# |とっしん|349|
# |すてみタックル|341|
# |ずつき|326|
# |じしん|322|
# |どろかけ|300|
# |スピードスター|281|
# |れいとうビーム|270|
# |かみなり|263|
# |なみのり|260|
# |いわくだき|258|
# |かいりき|257|
# |ロケットずつき|244|
# |でんじほう|228|
# |ふぶき|219|
#
# rl_loop_210227_1_hc_8 8
# |要素|出現回数|
# |---|---|
# |カビゴン|159|
# |バリヤード|77|
# |サンダー|76|
# |スターミー|69|
# |ラプラス|67|
# |ライコウ|56|
# |リングマ|55|
# |バンギラス|50|
# |ゲンガー|45|
# |デンリュウ|44|
# |スイクン|36|
# |ヌオー|35|
# |オムスター|35|
# |サンダース|33|
# |ハピナス|32|
# |ヤドキング|32|
# |メガニウム|31|
# |サイドン|30|
# |ヤドラン|29|
# |ルージュラ|27|
#
# |要素|出現回数|
# |---|---|
# |おんがえし|569|
# |どくどく|425|
# |１０まんボルト|387|
# |かげぶんしん|376|
# |すてみタックル|353|
# |とっしん|349|
# |ずつき|344|
# |はかいこうせん|336|
# |のしかかり|332|
# |どろかけ|317|
# |じしん|314|
# |スピードスター|283|
# |いわくだき|281|
# |サイコキネシス|267|
# |れいとうビーム|256|
# |かみなり|250|
# |ロケットずつき|243|
# |かいりき|240|
# |ふぶき|232|
# |でんじほう|232|
#
# rl_loop_210227_1_hc_9 9
# |要素|出現回数|
# |---|---|
# |スターミー|106|
# |サンダー|105|
# |カビゴン|87|
# |ライコウ|76|
# |バンギラス|60|
# |フーディン|51|
# |バクフーン|48|
# |キングドラ|44|
# |カイリュー|41|
# |ヤドラン|41|
# |スイクン|39|
# |ランターン|38|
# |プテラ|36|
# |ケンタロス|33|
# |ドンファン|32|
# |ゲンガー|30|
# |ファイヤー|30|
# |フシギバナ|30|
# |サンダース|29|
# |ラプラス|28|
#
# |要素|出現回数|
# |---|---|
# |おんがえし|615|
# |どくどく|413|
# |１０まんボルト|406|
# |すてみタックル|401|
# |かげぶんしん|400|
# |はかいこうせん|373|
# |じしん|357|
# |とっしん|344|
# |のしかかり|330|
# |ずつき|313|
# |どろかけ|305|
# |スピードスター|295|
# |れいとうビーム|288|
# |いわくだき|257|
# |なみのり|245|
# |サイコキネシス|244|
# |ロケットずつき|230|
# |かみなり|226|
# |かいりき|224|
# |でんじほう|217|
